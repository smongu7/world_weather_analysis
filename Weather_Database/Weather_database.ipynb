# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import pprint
import time
from datetime import datetime
import sys
sys.path.append("../")
from citipy import citipy
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Build URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Figure out how to retrieve weather description

# Loop through all the cities in our list.
# for i in range(len(cities)):
# Create endpoint URL with each city.
city_url = url + "&q=" + "mataura"
# Create endpoint URL with each city.
city_url = url + "&q=" + city.replace(" ","+")
    
# Parse the JSON and retrieve data.
city_weather = requests.get(city_url).json()


weather = city_weather["weather"][0]["description"]
print(weather)
# Out:
# overcast clouds

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1# Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather Description": weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | gat
# Processing Record 9 of Set 1 | wharton
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | haverfordwest
# Processing Record 14 of Set 1 | olafsvik
# Processing Record 15 of Set 1 | caravelas
# Processing Record 16 of Set 1 | margate
# Processing Record 17 of Set 1 | port hardy
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | kaspiysk
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | elizabeth city
# Processing Record 24 of Set 1 | guarapari
# Processing Record 25 of Set 1 | necochea
# Processing Record 26 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | vostok
# Processing Record 30 of Set 1 | changping
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | guadalupe y calvo
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | westport
# Processing Record 37 of Set 1 | lavrentiya
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | aklavik
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | airai
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | tarakan
# Processing Record 46 of Set 1 | kruisfontein
# Processing Record 47 of Set 1 | powassan
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | sioux lookout
# Processing Record 2 of Set 2 | grindavik
# Processing Record 3 of Set 2 | parabel
# Processing Record 4 of Set 2 | rio grande
# Processing Record 5 of Set 2 | broken hill
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | barahona
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | abha
# Processing Record 10 of Set 2 | reconquista
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | narsaq
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | chuy
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | lansing
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | cap-aux-meules
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | shingu
# Processing Record 21 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 2 | pyinmana
# Processing Record 23 of Set 2 | russell
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | auki
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | aranos
# Processing Record 29 of Set 2 | la ronge
# Processing Record 30 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 2 | soyo
# Processing Record 32 of Set 2 | korla
# Processing Record 33 of Set 2 | camopi
# Processing Record 34 of Set 2 | isangel
# Processing Record 35 of Set 2 | tazmalt
# Processing Record 36 of Set 2 | biltine
# Processing Record 37 of Set 2 | sistranda
# Processing Record 38 of Set 2 | souillac
# Processing Record 39 of Set 2 | torbay
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | penzance
# Processing Record 42 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | leh
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | alta floresta
# Processing Record 47 of Set 2 | constantine
# Processing Record 48 of Set 2 | bonfim
# Processing Record 49 of Set 2 | high rock
# Processing Record 50 of Set 2 | shubarshi
# Processing Record 1 of Set 3 | zhucheng
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | oussouye
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | sorland
# Processing Record 6 of Set 3 | tautira
# Processing Record 7 of Set 3 | cockburn town
# Processing Record 8 of Set 3 | kaitangata
# Processing Record 9 of Set 3 | yaan
# Processing Record 10 of Set 3 | katsuura
# Processing Record 11 of Set 3 | lebyazhye
# Processing Record 12 of Set 3 | thompson
# Processing Record 13 of Set 3 | vangaindrano
# Processing Record 14 of Set 3 | filadelfia
# Processing Record 15 of Set 3 | beira
# Processing Record 16 of Set 3 | touros
# Processing Record 17 of Set 3 | christchurch
# Processing Record 18 of Set 3 | vatra moldovitei
# Processing Record 19 of Set 3 | hervey bay
# Processing Record 20 of Set 3 | eyl
# Processing Record 21 of Set 3 | portland
# Processing Record 22 of Set 3 | mount isa
# Processing Record 23 of Set 3 | porto empedocle
# Processing Record 24 of Set 3 | hvammstangi
# City not found. Skipping...
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | roebourne
# Processing Record 27 of Set 3 | tiksi
# Processing Record 28 of Set 3 | meadow lake
# Processing Record 29 of Set 3 | manzil tamim
# City not found. Skipping...
# Processing Record 30 of Set 3 | hami
# Processing Record 31 of Set 3 | hermanus
# Processing Record 32 of Set 3 | topchikha
# Processing Record 33 of Set 3 | namibe
# Processing Record 34 of Set 3 | moba
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | dikson
# Processing Record 37 of Set 3 | buckeye
# Processing Record 38 of Set 3 | hobart
# Processing Record 39 of Set 3 | george
# Processing Record 40 of Set 3 | san patricio
# Processing Record 41 of Set 3 | calarasi
# Processing Record 42 of Set 3 | vaitape
# Processing Record 43 of Set 3 | yomou
# Processing Record 44 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 3 | mandalgovi
# Processing Record 46 of Set 3 | wyndham
# Processing Record 47 of Set 3 | belyy yar
# Processing Record 48 of Set 3 | san cristobal
# Processing Record 49 of Set 3 | port blair
# Processing Record 50 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | gornopravdinsk
# Processing Record 2 of Set 4 | marsassoum
# Processing Record 3 of Set 4 | fairbanks
# Processing Record 4 of Set 4 | half moon bay
# Processing Record 5 of Set 4 | linjiang
# Processing Record 6 of Set 4 | birao
# Processing Record 7 of Set 4 | magallanes
# Processing Record 8 of Set 4 | zeya
# Processing Record 9 of Set 4 | aykhal
# Processing Record 10 of Set 4 | laguna
# Processing Record 11 of Set 4 | oistins
# Processing Record 12 of Set 4 | buraydah
# Processing Record 13 of Set 4 | kapaa
# Processing Record 14 of Set 4 | panzhihua
# Processing Record 15 of Set 4 | taoudenni
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | batticaloa
# Processing Record 18 of Set 4 | nikolskoye
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | mahebourg
# Processing Record 21 of Set 4 | amapa
# Processing Record 22 of Set 4 | umm kaddadah
# Processing Record 23 of Set 4 | lagos
# Processing Record 24 of Set 4 | rawson
# Processing Record 25 of Set 4 | roswell
# Processing Record 26 of Set 4 | kendari
# Processing Record 27 of Set 4 | sitka
# Processing Record 28 of Set 4 | kutum
# Processing Record 29 of Set 4 | sawtell
# Processing Record 30 of Set 4 | east london
# Processing Record 31 of Set 4 | hovd
# Processing Record 32 of Set 4 | wonthaggi
# Processing Record 33 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 4 | san vicente
# Processing Record 35 of Set 4 | lagoa
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | dyersburg
# Processing Record 38 of Set 4 | aksarka
# Processing Record 39 of Set 4 | tabou
# Processing Record 40 of Set 4 | piacabucu
# Processing Record 41 of Set 4 | rey bouba
# Processing Record 42 of Set 4 | adrar
# Processing Record 43 of Set 4 | puno
# Processing Record 44 of Set 4 | nuuk
# Processing Record 45 of Set 4 | geraldton
# Processing Record 46 of Set 4 | college
# Processing Record 47 of Set 4 | ancud
# Processing Record 48 of Set 4 | bintulu
# Processing Record 49 of Set 4 | sola
# Processing Record 50 of Set 4 | shache
# Processing Record 1 of Set 5 | nanortalik
# Processing Record 2 of Set 5 | xapuri
# Processing Record 3 of Set 5 | ribeira grande
# Processing Record 4 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 5 | eureka
# Processing Record 6 of Set 5 | guerrero negro
# Processing Record 7 of Set 5 | dingle
# Processing Record 8 of Set 5 | high level
# Processing Record 9 of Set 5 | vao
# Processing Record 10 of Set 5 | nelson bay
# Processing Record 11 of Set 5 | igrim
# Processing Record 12 of Set 5 | bam
# Processing Record 13 of Set 5 | clyde river
# Processing Record 14 of Set 5 | locri
# Processing Record 15 of Set 5 | apricena
# Processing Record 16 of Set 5 | nicoya
# Processing Record 17 of Set 5 | lamar
# Processing Record 18 of Set 5 | araouane
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | baruun-urt
# Processing Record 21 of Set 5 | solnechnyy
# Processing Record 22 of Set 5 | tasiilaq
# Processing Record 23 of Set 5 | hasaki
# Processing Record 24 of Set 5 | saint anthony
# Processing Record 25 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 5 | mabay
# Processing Record 27 of Set 5 | manicore
# Processing Record 28 of Set 5 | kerrville
# Processing Record 29 of Set 5 | havoysund
# Processing Record 30 of Set 5 | bogoslovka
# Processing Record 31 of Set 5 | boralday
# Processing Record 32 of Set 5 | marawi
# Processing Record 33 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 5 | mount gambier
# Processing Record 35 of Set 5 | havelock
# Processing Record 36 of Set 5 | tiznit
# Processing Record 37 of Set 5 | noumea
# Processing Record 38 of Set 5 | lasa
# Processing Record 39 of Set 5 | nalut
# Processing Record 40 of Set 5 | banatski karlovac
# Processing Record 41 of Set 5 | udachnyy
# Processing Record 42 of Set 5 | ponta do sol
# Processing Record 43 of Set 5 | sao felix do xingu
# Processing Record 44 of Set 5 | druzhba
# Processing Record 45 of Set 5 | parana
# Processing Record 46 of Set 5 | aguie
# Processing Record 47 of Set 5 | saint george
# Processing Record 48 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 5 | sisimiut
# Processing Record 50 of Set 5 | surt
# Processing Record 1 of Set 6 | regeneracao
# Processing Record 2 of Set 6 | makakilo city
# Processing Record 3 of Set 6 | kodiak
# Processing Record 4 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 6 | nieuw amsterdam
# Processing Record 6 of Set 6 | abonnema
# Processing Record 7 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 8 of Set 6 | krasnoselkup
# Processing Record 9 of Set 6 | mansehra
# Processing Record 10 of Set 6 | porto nacional
# Processing Record 11 of Set 6 | harper
# Processing Record 12 of Set 6 | saint-augustin
# Processing Record 13 of Set 6 | bunol
# Processing Record 14 of Set 6 | ola
# Processing Record 15 of Set 6 | dongsheng
# Processing Record 16 of Set 6 | cayenne
# Processing Record 17 of Set 6 | kathu
# Processing Record 18 of Set 6 | moranbah
# Processing Record 19 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 6 | henderson
# Processing Record 21 of Set 6 | najibabad
# Processing Record 22 of Set 6 | bavleny
# Processing Record 23 of Set 6 | corner brook
# Processing Record 24 of Set 6 | kasempa
# Processing Record 25 of Set 6 | dinar
# Processing Record 26 of Set 6 | toora-khem
# Processing Record 27 of Set 6 | bandar
# Processing Record 28 of Set 6 | buala
# Processing Record 29 of Set 6 | khatanga
# Processing Record 30 of Set 6 | henties bay
# Processing Record 31 of Set 6 | makat
# Processing Record 32 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 33 of Set 6 | severo-kurilsk
# Processing Record 34 of Set 6 | kavaratti
# Processing Record 35 of Set 6 | pennathur
# Processing Record 36 of Set 6 | pavlodar
# Processing Record 37 of Set 6 | port keats
# Processing Record 38 of Set 6 | haines junction
# Processing Record 39 of Set 6 | port hedland
# Processing Record 40 of Set 6 | ayan
# Processing Record 41 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 42 of Set 6 | taunggyi
# Processing Record 43 of Set 6 | mercedes
# Processing Record 44 of Set 6 | isoka
# Processing Record 45 of Set 6 | luderitz
# Processing Record 46 of Set 6 | along
# Processing Record 47 of Set 6 | talcahuano
# Processing Record 48 of Set 6 | baherden
# Processing Record 49 of Set 6 | lompoc
# Processing Record 50 of Set 6 | hays
# Processing Record 1 of Set 7 | scarborough
# Processing Record 2 of Set 7 | eenhana
# Processing Record 3 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 7 | puerto carreno
# Processing Record 5 of Set 7 | beringovskiy
# Processing Record 6 of Set 7 | lima
# Processing Record 7 of Set 7 | sakakah
# Processing Record 8 of Set 7 | cherskiy
# Processing Record 9 of Set 7 | atar
# Processing Record 10 of Set 7 | batagay-alyta
# Processing Record 11 of Set 7 | tessaoua
# Processing Record 12 of Set 7 | zhigansk
# Processing Record 13 of Set 7 | carutapera
# Processing Record 14 of Set 7 | awbari
# Processing Record 15 of Set 7 | tura
# Processing Record 16 of Set 7 | vardo
# Processing Record 17 of Set 7 | sawang daen din
# Processing Record 18 of Set 7 | korcula
# Processing Record 19 of Set 7 | urumqi
# Processing Record 20 of Set 7 | fortuna
# Processing Record 21 of Set 7 | puerto montt
# Processing Record 22 of Set 7 | padang
# Processing Record 23 of Set 7 | sarangani
# Processing Record 24 of Set 7 | ust-ordynskiy
# Processing Record 25 of Set 7 | codrington
# Processing Record 26 of Set 7 | colac
# Processing Record 27 of Set 7 | dolores hidalgo
# Processing Record 28 of Set 7 | bilma
# Processing Record 29 of Set 7 | yarmouth
# Processing Record 30 of Set 7 | koumac
# Processing Record 31 of Set 7 | chokurdakh
# Processing Record 32 of Set 7 | outjo
# Processing Record 33 of Set 7 | matane
# Processing Record 34 of Set 7 | tuy hoa
# Processing Record 35 of Set 7 | tanete
# Processing Record 36 of Set 7 | linxia
# Processing Record 37 of Set 7 | bathsheba
# Processing Record 38 of Set 7 | kieta
# Processing Record 39 of Set 7 | mitsamiouli
# Processing Record 40 of Set 7 | sanming
# Processing Record 41 of Set 7 | bengkulu
# Processing Record 42 of Set 7 | kingman
# Processing Record 43 of Set 7 | boguchany
# Processing Record 44 of Set 7 | sao paulo de olivenca
# Processing Record 45 of Set 7 | kudahuvadhoo
# Processing Record 46 of Set 7 | ilulissat
# Processing Record 47 of Set 7 | languyan
# Processing Record 48 of Set 7 | seoul
# Processing Record 49 of Set 7 | svetlaya
# Processing Record 50 of Set 7 | cap malheureux
# Processing Record 1 of Set 8 | goundam
# Processing Record 2 of Set 8 | dakar
# Processing Record 3 of Set 8 | kashi
# Processing Record 4 of Set 8 | kalengwa
# Processing Record 5 of Set 8 | santa cruz cabralia
# Processing Record 6 of Set 8 | mocuba
# Processing Record 7 of Set 8 | bouar
# Processing Record 8 of Set 8 | namatanai
# Processing Record 9 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 8 | zasechnoye
# Processing Record 11 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 12 of Set 8 | saint-philippe
# Processing Record 13 of Set 8 | nemuro
# Processing Record 14 of Set 8 | jibuti
# Processing Record 15 of Set 8 | antofagasta
# Processing Record 16 of Set 8 | severodvinsk
# Processing Record 17 of Set 8 | okhotsk
# Processing Record 18 of Set 8 | champawat
# Processing Record 19 of Set 8 | astana
# Processing Record 20 of Set 8 | suluova
# Processing Record 21 of Set 8 | aldan
# Processing Record 22 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 8 | tocopilla
# Processing Record 24 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 8 | vila franca do campo
# Processing Record 26 of Set 8 | pinotepa nacional
# Processing Record 27 of Set 8 | yar-sale
# Processing Record 28 of Set 8 | san quintin
# Processing Record 29 of Set 8 | zunyi
# Processing Record 30 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 8 | san ignacio
# Processing Record 32 of Set 8 | chimoio
# Processing Record 33 of Set 8 | sobolevo
# Processing Record 34 of Set 8 | inhambane
# Processing Record 35 of Set 8 | vestmannaeyjar
# Processing Record 36 of Set 8 | nauta
# Processing Record 37 of Set 8 | los llanos de aridane
# Processing Record 38 of Set 8 | sao joao da barra
# Processing Record 39 of Set 8 | kartuzy
# Processing Record 40 of Set 8 | la solana
# Processing Record 41 of Set 8 | sokoni
# Processing Record 42 of Set 8 | faya
# Processing Record 43 of Set 8 | ponta delgada
# Processing Record 44 of Set 8 | rio gallegos
# Processing Record 45 of Set 8 | leninskoye
# Processing Record 46 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 8 | jalu
# Processing Record 48 of Set 8 | khandagayty
# Processing Record 49 of Set 8 | mishelevka
# Processing Record 50 of Set 8 | usinsk
# Processing Record 1 of Set 9 | dunedin
# Processing Record 2 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 9 | shaartuz
# City not found. Skipping...
# Processing Record 4 of Set 9 | alofi
# Processing Record 5 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 9 | panji
# Processing Record 7 of Set 9 | kirakira
# Processing Record 8 of Set 9 | waw
# Processing Record 9 of Set 9 | sayat
# Processing Record 10 of Set 9 | ahome
# Processing Record 11 of Set 9 | belmonte
# Processing Record 12 of Set 9 | talnakh
# Processing Record 13 of Set 9 | mizdah
# Processing Record 14 of Set 9 | provost
# Processing Record 15 of Set 9 | ahipara
# Processing Record 16 of Set 9 | kavieng
# Processing Record 17 of Set 9 | sur
# Processing Record 18 of Set 9 | arlit
# Processing Record 19 of Set 9 | sibu
# Processing Record 20 of Set 9 | kargil
# Processing Record 21 of Set 9 | mizan teferi
# Processing Record 22 of Set 9 | opoczno
# Processing Record 23 of Set 9 | tolbazy
# Processing Record 24 of Set 9 | norman wells
# Processing Record 25 of Set 9 | hanzhong
# Processing Record 26 of Set 9 | comodoro rivadavia
# Processing Record 27 of Set 9 | uusikaupunki
# Processing Record 28 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 9 | sinnamary
# Processing Record 30 of Set 9 | santa maria
# Processing Record 31 of Set 9 | oyama
# Processing Record 32 of Set 9 | crnomelj
# Processing Record 33 of Set 9 | qui nhon
# Processing Record 34 of Set 9 | waddan
# Processing Record 35 of Set 9 | kralendijk
# Processing Record 36 of Set 9 | matamoros
# Processing Record 37 of Set 9 | vyartsilya
# Processing Record 38 of Set 9 | cicero dantas
# Processing Record 39 of Set 9 | semey
# Processing Record 40 of Set 9 | moron
# Processing Record 41 of Set 9 | yatou
# Processing Record 42 of Set 9 | ampere
# Processing Record 43 of Set 9 | queanbeyan
# Processing Record 44 of Set 9 | norrtalje
# Processing Record 45 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 9 | wadi maliz
# Processing Record 47 of Set 9 | kijang
# Processing Record 48 of Set 9 | zhezkazgan
# Processing Record 49 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 10 | price
# Processing Record 2 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 3 of Set 10 | broome
# Processing Record 4 of Set 10 | sao filipe
# Processing Record 5 of Set 10 | kizilskoye
# Processing Record 6 of Set 10 | dzaoudzi
# Processing Record 7 of Set 10 | victoria
# Processing Record 8 of Set 10 | mayo
# Processing Record 9 of Set 10 | bilibino
# Processing Record 10 of Set 10 | aguimes
# Processing Record 11 of Set 10 | ankang
# Processing Record 12 of Set 10 | leonidion
# City not found. Skipping...
# Processing Record 13 of Set 10 | santa cruz
# Processing Record 14 of Set 10 | kyren
# Processing Record 15 of Set 10 | berlevag
# Processing Record 16 of Set 10 | salalah
# Processing Record 17 of Set 10 | sandwick
# Processing Record 18 of Set 10 | clifton
# Processing Record 19 of Set 10 | yunyang
# Processing Record 20 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 10 | yerbogachen
# Processing Record 22 of Set 10 | gizo
# Processing Record 23 of Set 10 | pangnirtung
# Processing Record 24 of Set 10 | igarka
# Processing Record 25 of Set 10 | krasnorechenskiy
# Processing Record 26 of Set 10 | amahai
# Processing Record 27 of Set 10 | kenai
# Processing Record 28 of Set 10 | general pico
# Processing Record 29 of Set 10 | poum
# Processing Record 30 of Set 10 | coquimbo
# Processing Record 31 of Set 10 | ciudad bolivar
# Processing Record 32 of Set 10 | port lincoln
# Processing Record 33 of Set 10 | gorontalo
# Processing Record 34 of Set 10 | strelka
# Processing Record 35 of Set 10 | kloulklubed
# Processing Record 36 of Set 10 | ust-karsk
# Processing Record 37 of Set 10 | tawang
# Processing Record 38 of Set 10 | kupang
# Processing Record 39 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 40 of Set 10 | alihe
# Processing Record 41 of Set 10 | scottsbluff
# Processing Record 42 of Set 10 | gigmoto
# Processing Record 43 of Set 10 | kibaya
# Processing Record 44 of Set 10 | port augusta
# Processing Record 45 of Set 10 | tanjong sepat
# City not found. Skipping...
# Processing Record 46 of Set 10 | puga
# Processing Record 47 of Set 10 | zhuhai
# Processing Record 48 of Set 10 | praia
# Processing Record 49 of Set 10 | mildura
# Processing Record 50 of Set 10 | pullman
# Processing Record 1 of Set 11 | baykalovo
# Processing Record 2 of Set 11 | komsomolskiy
# Processing Record 3 of Set 11 | pacific grove
# Processing Record 4 of Set 11 | eckernforde
# Processing Record 5 of Set 11 | havre-saint-pierre
# Processing Record 6 of Set 11 | batagay
# Processing Record 7 of Set 11 | sovetskiy
# Processing Record 8 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 9 of Set 11 | martapura
# Processing Record 10 of Set 11 | panama city
# Processing Record 11 of Set 11 | makaha
# Processing Record 12 of Set 11 | ayr
# Processing Record 13 of Set 11 | togur
# Processing Record 14 of Set 11 | flinders
# Processing Record 15 of Set 11 | porto novo
# Processing Record 16 of Set 11 | kambove
# Processing Record 17 of Set 11 | dali
# Processing Record 18 of Set 11 | san lawrenz
# Processing Record 19 of Set 11 | kalininsk
# Processing Record 20 of Set 11 | faanui
# Processing Record 21 of Set 11 | mooi river
# City not found. Skipping...
# Processing Record 22 of Set 11 | tazovskiy
# Processing Record 23 of Set 11 | vila velha
# Processing Record 24 of Set 11 | pundaguitan
# Processing Record 25 of Set 11 | baiquan
# Processing Record 26 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 27 of Set 11 | tucuma
# Processing Record 28 of Set 11 | albanel
# Processing Record 29 of Set 11 | drayton valley
# Processing Record 30 of Set 11 | odweyne
# Processing Record 31 of Set 11 | aliwal north
# Processing Record 32 of Set 11 | thinadhoo
# Processing Record 33 of Set 11 | te anau
# Processing Record 34 of Set 11 | san policarpo
# Processing Record 35 of Set 11 | saint-joseph
# Processing Record 36 of Set 11 | aswan
# Processing Record 37 of Set 11 | marzuq
# Processing Record 38 of Set 11 | koutsouras
# Processing Record 39 of Set 11 | naze
# Processing Record 40 of Set 11 | wanning
# Processing Record 41 of Set 11 | kuala terengganu
# Processing Record 42 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 11 | bowen
# Processing Record 44 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 11 | maralal
# Processing Record 47 of Set 11 | vestmanna
# Processing Record 48 of Set 11 | vieira de leiria
# Processing Record 49 of Set 11 | chupa
# Processing Record 50 of Set 11 | angoche
# Processing Record 1 of Set 12 | santa cecilia
# Processing Record 2 of Set 12 | ye
# City not found. Skipping...
# Processing Record 3 of Set 12 | rio blanco
# Processing Record 4 of Set 12 | canitas
# City not found. Skipping...
# Processing Record 5 of Set 12 | husavik
# Processing Record 6 of Set 12 | hilvarenbeek
# Processing Record 7 of Set 12 | nome
# Processing Record 8 of Set 12 | pontes e lacerda
# Processing Record 9 of Set 12 | verkhovazhye
# Processing Record 10 of Set 12 | bhabua
# Processing Record 11 of Set 12 | nerchinskiy zavod
# Processing Record 12 of Set 12 | freetown
# Processing Record 13 of Set 12 | hohhot
# Processing Record 14 of Set 12 | pervomayskoye
# Processing Record 15 of Set 12 | coari
# Processing Record 16 of Set 12 | suileng
# Processing Record 17 of Set 12 | samarai
# Processing Record 18 of Set 12 | sabha
# Processing Record 19 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 20 of Set 12 | olesnica
# Processing Record 21 of Set 12 | kitimat
# Processing Record 22 of Set 12 | evensk
# Processing Record 23 of Set 12 | hattiesburg
# Processing Record 24 of Set 12 | yazman
# Processing Record 25 of Set 12 | aljezur
# Processing Record 26 of Set 12 | acarau
# Processing Record 27 of Set 12 | ivnya
# Processing Record 28 of Set 12 | knysna
# Processing Record 29 of Set 12 | van
# Processing Record 30 of Set 12 | saint-pierre
# Processing Record 31 of Set 12 | sydney mines
# Processing Record 32 of Set 12 | lorengau
# Processing Record 33 of Set 12 | chapais
# Processing Record 34 of Set 12 | tainan
# Processing Record 35 of Set 12 | kyzyl-suu
# Processing Record 36 of Set 12 | semaria
# Processing Record 37 of Set 12 | hofn
# Processing Record 38 of Set 12 | tanda
# Processing Record 39 of Set 12 | constitucion
# Processing Record 40 of Set 12 | pangai
# Processing Record 41 of Set 12 | ravar
# Processing Record 42 of Set 12 | hambantota
# Processing Record 43 of Set 12 | nabire
# Processing Record 44 of Set 12 | fountain
# Processing Record 45 of Set 12 | gelemso
# Processing Record 46 of Set 12 | puerto baquerizo moreno
# Processing Record 47 of Set 12 | pyaozerskiy
# Processing Record 48 of Set 12 | riyadh
# Processing Record 49 of Set 12 | walvis bay
# Processing Record 50 of Set 12 | isiro
# Processing Record 1 of Set 13 | torbeyevo
# Processing Record 2 of Set 13 | lelystad
# Processing Record 3 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 13 | charters towers
# Processing Record 6 of Set 13 | iralaya
# Processing Record 7 of Set 13 | mezen
# Processing Record 8 of Set 13 | puerto colombia
# Processing Record 9 of Set 13 | cairns
# Processing Record 10 of Set 13 | belaya gora
# Processing Record 11 of Set 13 | zhuanghe
# Processing Record 12 of Set 13 | moose factory
# Processing Record 13 of Set 13 | ormara
# Processing Record 14 of Set 13 | katobu
# Processing Record 15 of Set 13 | anadyr
# Processing Record 16 of Set 13 | road town
# Processing Record 17 of Set 13 | farafangana
# Processing Record 18 of Set 13 | bassano
# Processing Record 19 of Set 13 | eskisehir
# Processing Record 20 of Set 13 | itarema
# Processing Record 21 of Set 13 | mahajanga
# Processing Record 22 of Set 13 | villa alemana
# Processing Record 23 of Set 13 | luang prabang
# Processing Record 24 of Set 13 | ludvika
# Processing Record 25 of Set 13 | ust-omchug
# Processing Record 26 of Set 13 | asheboro
# Processing Record 27 of Set 13 | tommot
# Processing Record 28 of Set 13 | nioro
# Processing Record 29 of Set 13 | northam
# Processing Record 30 of Set 13 | hirtshals
# Processing Record 31 of Set 13 | itarana
# Processing Record 32 of Set 13 | quelimane
# Processing Record 33 of Set 13 | zhigalovo
# Processing Record 34 of Set 13 | sabang
# Processing Record 35 of Set 13 | middle island
# Processing Record 36 of Set 13 | tucurui
# Processing Record 37 of Set 13 | surazh
# Processing Record 38 of Set 13 | raudeberg
# Processing Record 39 of Set 13 | fairview
# Processing Record 40 of Set 13 | kibondo
# Processing Record 41 of Set 13 | paka
# Processing Record 42 of Set 13 | ucluelet
# Processing Record 43 of Set 13 | foso
# Processing Record 44 of Set 13 | zima
# Processing Record 45 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 46 of Set 13 | plainview
# Processing Record 47 of Set 13 | flagstaff
# Processing Record 48 of Set 13 | sao jose da coroa grande
# Processing Record 49 of Set 13 | natal
# Processing Record 50 of Set 13 | chaa-khol
# City not found. Skipping...
# Processing Record 1 of Set 14 | waihi beach
# Processing Record 2 of Set 14 | sharan
# Processing Record 3 of Set 14 | bambanglipuro
# Processing Record 4 of Set 14 | dabola
# Processing Record 5 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 6 of Set 14 | turtas
# Processing Record 7 of Set 14 | valdivia
# Processing Record 8 of Set 14 | pangody
# Processing Record 9 of Set 14 | kysyl-syr
# Processing Record 10 of Set 14 | suez
# Processing Record 11 of Set 14 | beloha
# Processing Record 12 of Set 14 | rafai
# Processing Record 13 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 14 of Set 14 | amuntai
# Processing Record 15 of Set 14 | angoram
# Processing Record 16 of Set 14 | richards bay
# Processing Record 17 of Set 14 | inhambupe
# Processing Record 18 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 19 of Set 14 | savannah bight
# Processing Record 20 of Set 14 | mnogovershinnyy
# Processing Record 21 of Set 14 | listvyagi
# Processing Record 22 of Set 14 | vila do maio
# Processing Record 23 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 24 of Set 14 | port-gentil
# Processing Record 25 of Set 14 | gimli
# Processing Record 26 of Set 14 | ondjiva
# Processing Record 27 of Set 14 | bo phloi
# Processing Record 28 of Set 14 | bisho
# Processing Record 29 of Set 14 | mehamn
# Processing Record 30 of Set 14 | lata
# Processing Record 31 of Set 14 | severo-yeniseyskiy
# Processing Record 32 of Set 14 | moses lake
# Processing Record 33 of Set 14 | turangi
# Processing Record 34 of Set 14 | sambava
# Processing Record 35 of Set 14 | puerto del rosario
# Processing Record 36 of Set 14 | saint-georges
# Processing Record 37 of Set 14 | la palma
# Processing Record 38 of Set 14 | quatre cocos
# Processing Record 39 of Set 14 | andenes
# Processing Record 40 of Set 14 | moundou
# Processing Record 41 of Set 14 | tabas
# Processing Record 42 of Set 14 | bud
# Processing Record 43 of Set 14 | zalantun
# Processing Record 44 of Set 14 | pemangkat
# Processing Record 45 of Set 14 | yibin
# Processing Record 46 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 14 | jipapad
# Processing Record 48 of Set 14 | solwezi
# Processing Record 49 of Set 14 | mako
# Processing Record 50 of Set 14 | shimoda
# Processing Record 1 of Set 15 | qadirpur ran
# Processing Record 2 of Set 15 | gondar
# Processing Record 3 of Set 15 | the pas
# Processing Record 4 of Set 15 | sumter
# Processing Record 5 of Set 15 | verkhnevilyuysk
# Processing Record 6 of Set 15 | qaqortoq
# Processing Record 7 of Set 15 | jimma
# Processing Record 8 of Set 15 | osoyoos
# Processing Record 9 of Set 15 | okha
# Processing Record 10 of Set 15 | prince george
# Processing Record 11 of Set 15 | koubia
# Processing Record 12 of Set 15 | weston
# Processing Record 13 of Set 15 | rosarito
# Processing Record 14 of Set 15 | biak
# Processing Record 15 of Set 15 | agadez
# Processing Record 16 of Set 15 | luena
# Processing Record 17 of Set 15 | monaragala
# Processing Record 18 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 19 of Set 15 | kinshasa
# Processing Record 20 of Set 15 | clarksville
# Processing Record 21 of Set 15 | inuvik
# Processing Record 22 of Set 15 | wolmaranstad
# City not found. Skipping...
# Processing Record 23 of Set 15 | najran
# Processing Record 24 of Set 15 | pamantingan
# Processing Record 25 of Set 15 | comal
# Processing Record 26 of Set 15 | farah
# Processing Record 27 of Set 15 | saint-denis
# Processing Record 28 of Set 15 | akcakoca
# Processing Record 29 of Set 15 | yaval
# Processing Record 30 of Set 15 | am timan
# Processing Record 31 of Set 15 | okakarara
# Processing Record 32 of Set 15 | kharp
# Processing Record 33 of Set 15 | badarpur
# Processing Record 34 of Set 15 | ambilobe
# Processing Record 35 of Set 15 | novobirilyussy
# Processing Record 36 of Set 15 | yeppoon
# Processing Record 37 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 38 of Set 15 | bubaque
# Processing Record 39 of Set 15 | villa bruzual
# Processing Record 40 of Set 15 | finschhafen
# Processing Record 41 of Set 15 | nenjiang
# Processing Record 42 of Set 15 | south venice
# Processing Record 43 of Set 15 | bukachacha
# Processing Record 44 of Set 15 | sheregesh
# Processing Record 45 of Set 15 | kyzyl
# Processing Record 46 of Set 15 | choctaw
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Pevek  69.7008  170.3133    -25.64        98         100
# 1        Avarua -21.2078 -159.7750     71.65       100          92
# 2  Longyearbyen  78.2186   15.6401     12.04        73           0
# 3   New Norfolk -42.7826  147.0587     56.70        59          92
# 4         Bluff -46.6000  168.3333     51.80        65          75
# 5    Bredasdorp -34.5322   20.0403     74.52        64          47
# 6           Gat  31.6100   34.7642     61.48        16           0
# 7       Wharton  29.3116  -96.1027     61.92       100          40
# 8   Port Alfred -33.5906   26.8910     79.20        83           8
# 9     Carnarvon -24.8667  113.6333     82.47        69           7
#
#    Wind Speed Country                 Date Weather Description
# 0        8.61      RU  2022-02-12 15:51:16     overcast clouds
# 1        1.14      CK  2022-02-12 15:51:16     overcast clouds
# 2       14.97      SJ  2022-02-12 15:51:17           clear sky
# 3        2.64      AU  2022-02-12 15:51:17     overcast clouds
# 4       14.34      NZ  2022-02-12 15:51:17       broken clouds
# 5       11.50      ZA  2022-02-12 15:51:18    scattered clouds
# 6        7.09      IL  2022-02-12 15:51:18           clear sky
# 7        6.91      US  2022-02-12 15:51:18    scattered clouds
# 8       18.43      ZA  2022-02-12 15:51:19           clear sky
# 9       12.66      AU  2022-02-12 15:51:19           clear sky

# %%
# Drop "Date" column
city_data_df.pop('Date')
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Pevek  69.7008  170.3133    -25.64        98         100
# 1        Avarua -21.2078 -159.7750     71.65       100          92
# 2  Longyearbyen  78.2186   15.6401     12.04        73           0
# 3   New Norfolk -42.7826  147.0587     56.70        59          92
# 4         Bluff -46.6000  168.3333     51.80        65          75
# 5    Bredasdorp -34.5322   20.0403     74.52        64          47
# 6           Gat  31.6100   34.7642     61.48        16           0
# 7       Wharton  29.3116  -96.1027     61.92       100          40
# 8   Port Alfred -33.5906   26.8910     79.20        83           8
# 9     Carnarvon -24.8667  113.6333     82.47        69           7
#
#    Wind Speed Country Weather Description
# 0        8.61      RU     overcast clouds
# 1        1.14      CK     overcast clouds
# 2       14.97      SJ           clear sky
# 3        2.64      AU     overcast clouds
# 4       14.34      NZ       broken clouds
# 5       11.50      ZA    scattered clouds
# 6        7.09      IL           clear sky
# 7        6.91      US    scattered clouds
# 8       18.43      ZA           clear sky
# 9       12.66      AU           clear sky

# %%
# Rearrange columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Pevek      RU  69.7008  170.3133    -25.64        98         100
# 1        Avarua      CK -21.2078 -159.7750     71.65       100          92
# 2  Longyearbyen      SJ  78.2186   15.6401     12.04        73           0
# 3   New Norfolk      AU -42.7826  147.0587     56.70        59          92
# 4         Bluff      NZ -46.6000  168.3333     51.80        65          75
# 5    Bredasdorp      ZA -34.5322   20.0403     74.52        64          47
# 6           Gat      IL  31.6100   34.7642     61.48        16           0
# 7       Wharton      US  29.3116  -96.1027     61.92       100          40
# 8   Port Alfred      ZA -33.5906   26.8910     79.20        83           8
# 9     Carnarvon      AU -24.8667  113.6333     82.47        69           7
#
#    Wind Speed Weather Description
# 0        8.61     overcast clouds
# 1        1.14     overcast clouds
# 2       14.97           clear sky
# 3        2.64     overcast clouds
# 4       14.34       broken clouds
# 5       11.50    scattered clouds
# 6        7.09           clear sky
# 7        6.91    scattered clouds
# 8       18.43           clear sky
# 9       12.66           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
